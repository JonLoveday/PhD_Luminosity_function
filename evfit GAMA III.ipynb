# %%
import pandas as pd
df = pd.read_pickle('dataframe_GAMAIII_ugriZ.pkl')
from PhD_Luminosity_function_final import *
from evfit import *

# %%
df = df.rename(columns={'Z': 'Z_TONRY'})

# %%
df
# Out:
#                  uberID       RAcen    Deccen       RAmax    Decmax  \
# 0       128980003711188  129.579930 -1.029780  129.579933 -1.029784
# 1       128980004608892  129.579121 -1.246004  129.579142 -1.245971
# 2       128980005210530  129.578549 -1.091716  129.578537 -1.091739
# 3       128980005309861  129.578474 -1.154733  129.578459 -1.154730
# 4       128980008210800  129.575720 -1.066314  129.575705 -1.066317
# ...                 ...         ...       ...         ...       ...
# 153954  224021222504535  223.031751  2.343636  223.031720  2.343569
# 153955  224021225210755  223.028958  2.929282  223.028921  2.929247
# 153956  224021226105464  223.028218  2.431092  223.028290  2.431043
# 153957  224021228202966  223.026430  2.195831  223.026413  2.195829
# 153958  224021236909349  223.017997  2.796850  223.017949  2.796855
#
#             RAGAIA   DecGAIA      sky_mean   skyRMS_mean  log10seeing  ...  \
# ...

# %%
ev_fit(infile=df, outfile='test.fits', mlims=(0, 19.72), param='m_r', Mmin=-24, Mmax=-14, Mbin=40, method='lfchi', survey='GAMAIII', area=180, kc_responses=['vst_u', 'vst_g', 'vst_r', 'vst_i', 'vista_z'], r_band_index=2)
# Out:
# ('lambda', 'pass')
# ('lambda', 'pass')
# ('lambda', 'pass')
# ('lambda', 'pass')
# ('lambda', 'pass')
# C:\Users\adrie\anaconda3\lib\site-packages\kcorrect\template.py:221: RuntimeWarning: underflow encountered in divide
#   self.flux = self.restframe_flux / (1. + redshift)
# ************************
# jswml.py version  1.1
# lfchi
# {}
# CosmoLookup: H0=100.0, Omega_l=0.7, P=1
# H0, omega_l, z0, area/Sr =  100.0 0.7 0 0.05483113556160754
# 153959 galaxies selected
# No column r_sb; ignoring SB completeness
# No column fibermag_r; ignoring redshift completeness
# Setting LF bin limits Qmin, Qmax =  0.0 1.5
# zlo, zhi, Mmin, Mmax, nbins
# 0.002 0.2013846153846154 -39.41093539387206 -9.17372686180397 37
# LF bins at Qmin:  [   0    0    3   16   35   86  211  480  942 1500 2300 3219 4078 5061
#  5983 6782 7533 7053 5827 4784 3718 2888 2184 1660 1343 1220  837  552
#   538  473  309  238  210  166  145   98   89   61   38   23]
# ...
